# %%
from requests import get
from pyquery import PyQuery
from lxml.html import parse
from html.parser import HTMLParser
from bs4 import BeautifulSoup
from fpdf import FPDF
import os
import img2pdf
from flask import Flask, request, jsonify, json, abort
from flask_cors import CORS, cross_origin

# %%
url_ = "http://chessmoba.us/reader/reader/182/669064"

r = get(url_)
title = 'Shingek118'

directory = '/home/karan/Downloads/' + title + '/'
#os.mkdir(directory)

html = BeautifulSoup(r.content,"html.parser")

count = 0

img_arr = []

for img_page in html.find_all("img", class_="owl-lazy"):
    #print(img_page)
    count = count + 1
    print(img_page.attrs['data-src'])
    
    if count < 10:
        count_str = "0" + str(count)
    else:
        count_str = str(count)
            
    c = get(img_page.attrs['data-src'])
        
    img_arr.append('/home/karan/Downloads/' + title + '/' + title + (count_str) + ".jpg")
        
    with open('/home/karan/Downloads/' + title + '/' + title + (count_str) + ".jpg", 'wb') as f:
        f.write(c.content)
        print(title + (count_str))
            
print(img_arr)
# Out:
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/1.jpg
# Shingek11801
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/2.jpg
# Shingek11802
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/3.jpg
# Shingek11803
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/4.jpg
# Shingek11804
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/5.jpg
# Shingek11805
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/6.jpg
# Shingek11806
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/7.jpg
# Shingek11807
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/8.jpg
# Shingek11808
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/9.jpg
# Shingek11809
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/10.jpg
# Shingek11810
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/11.jpg
# Shingek11811
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/12.jpg
# Shingek11812
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/13.jpg
# Shingek11813
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/14.jpg
# Shingek11814
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/15.jpg
# Shingek11815
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/16.jpg
# Shingek11816
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/17.jpg
# Shingek11817
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/18.jpg
# Shingek11818
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/19.jpg
# Shingek11819
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/20.jpg
# Shingek11820
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/21.jpg
# Shingek11821
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/22.jpg
# Shingek11822
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/23.jpg
# Shingek11823
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/24.jpg
# Shingek11824
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/25.jpg
# Shingek11825
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/26.jpg
# Shingek11826
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/27.jpg
# Shingek11827
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/28.jpg
# Shingek11828
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/29.jpg
# Shingek11829
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/30.jpg
# Shingek11830
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/31.jpg
# Shingek11831
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/32.jpg
# Shingek11832
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/33.jpg
# Shingek11833
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/34.jpg
# Shingek11834
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/35.jpg
# Shingek11835
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/36.jpg
# Shingek11836
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/37.jpg
# Shingek11837
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/38.jpg
# Shingek11838
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/39.jpg
# Shingek11839
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/40.jpg
# Shingek11840
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/41.jpg
# Shingek11841
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/42.jpg
# Shingek11842
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/43.jpg
# Shingek11843
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/44.jpg
# Shingek11844
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/45.jpg
# Shingek11845
# https://s8.mkklcdnv8.com/mangakakalot/k2/kxqh9261558062112/vol29_chapter_118_foul_play/46.jpg
# Shingek11846
# ['/home/karan/Downloads/Shingek118/Shingek11801.jpg', '/home/karan/Downloads/Shingek118/Shingek11802.jpg', '/home/karan/Downloads/Shingek118/Shingek11803.jpg', '/home/karan/Downloads/Shingek118/Shingek11804.jpg', '/home/karan/Downloads/Shingek118/Shingek11805.jpg', '/home/karan/Downloads/Shingek118/Shingek11806.jpg', '/home/karan/Downloads/Shingek118/Shingek11807.jpg', '/home/karan/Downloads/Shingek118/Shingek11808.jpg', '/home/karan/Downloads/Shingek118/Shingek11809.jpg', '/home/karan/Downloads/Shingek118/Shingek11810.jpg', '/home/karan/Downloads/Shingek118/Shingek11811.jpg', '/home/karan/Downloads/Shingek118/Shingek11812.jpg', '/home/karan/Downloads/Shingek118/Shingek11813.jpg', '/home/karan/Downloads/Shingek118/Shingek11814.jpg', '/home/karan/Downloads/Shingek118/Shingek11815.jpg', '/home/karan/Downloads/Shingek118/Shingek11816.jpg', '/home/karan/Downloads/Shingek118/Shingek11817.jpg', '/home/karan/Downloads/Shingek118/Shingek11818.jpg', '/home/karan/Downloads/Shingek118/Shingek11819.jpg', '/home/karan/Downloads/Shingek118/Shingek11820.jpg', '/home/karan/Downloads/Shingek118/Shingek11821.jpg', '/home/karan/Downloads/Shingek118/Shingek11822.jpg', '/home/karan/Downloads/Shingek118/Shingek11823.jpg', '/home/karan/Downloads/Shingek118/Shingek11824.jpg', '/home/karan/Downloads/Shingek118/Shingek11825.jpg', '/home/karan/Downloads/Shingek118/Shingek11826.jpg', '/home/karan/Downloads/Shingek118/Shingek11827.jpg', '/home/karan/Downloads/Shingek118/Shingek11828.jpg', '/home/karan/Downloads/Shingek118/Shingek11829.jpg', '/home/karan/Downloads/Shingek118/Shingek11830.jpg', '/home/karan/Downloads/Shingek118/Shingek11831.jpg', '/home/karan/Downloads/Shingek118/Shingek11832.jpg', '/home/karan/Downloads/Shingek118/Shingek11833.jpg', '/home/karan/Downloads/Shingek118/Shingek11834.jpg', '/home/karan/Downloads/Shingek118/Shingek11835.jpg', '/home/karan/Downloads/Shingek118/Shingek11836.jpg', '/home/karan/Downloads/Shingek118/Shingek11837.jpg', '/home/karan/Downloads/Shingek118/Shingek11838.jpg', '/home/karan/Downloads/Shingek118/Shingek11839.jpg', '/home/karan/Downloads/Shingek118/Shingek11840.jpg', '/home/karan/Downloads/Shingek118/Shingek11841.jpg', '/home/karan/Downloads/Shingek118/Shingek11842.jpg', '/home/karan/Downloads/Shingek118/Shingek11843.jpg', '/home/karan/Downloads/Shingek118/Shingek11844.jpg', '/home/karan/Downloads/Shingek118/Shingek11845.jpg', '/home/karan/Downloads/Shingek118/Shingek11846.jpg']

# %%
url_ = "https://www.porncomix.info/watching-my-step-jab-comix/"
url = ('https://www.porncomix.info/jabcomix-santo-playa-no-2/jabcomix-santo-playa-no-2-1/')
r = get(url_)
title = 'Step_sis_'

directory = '/home/karan/Downloads/' + title + '/'
os.mkdir(directory)

# %%
html = BeautifulSoup(r.content,"html.parser")

count = 0

img_arr = []

for img_page in html.find_all("dt", class_="gallery-icon portrait"):
    #print(img_page)    
    for a in img_page.find_all("a", href=True):
        count = count + 1
        #print(a.attrs['href'])
        b = get(a.attrs['href'])
        
        if count < 10:
            count_str = "0" + str(count)
        else:
            count_str = str(count)
        
        page_img = BeautifulSoup(b.content,"html.parser").find_all("div", class_="attachment-image")[0].find_all("a", href=True)[0].attrs['href']
        
        c = get(page_img)
        
        img_arr.append('/home/karan/Downloads/' + title + '/' + title + (count_str) + ".jpg")
        
        with open('/home/karan/Downloads/' + title + '/' + title + (count_str) + ".jpg", 'wb') as f:
            f.write(c.content)
            print(title + (count_str))
            
print(img_arr)
# Out:
# Step_sis_01
# Step_sis_02
# Step_sis_03
# Step_sis_04
# Step_sis_05
# Step_sis_06
# Step_sis_07
# Step_sis_08
# Step_sis_09
# Step_sis_10
# Step_sis_11
# Step_sis_12
# Step_sis_13
# Step_sis_14
# Step_sis_15
# Step_sis_16
# Step_sis_17
# Step_sis_18
# Step_sis_19
# Step_sis_20
# Step_sis_21
# Step_sis_22
# Step_sis_23
# ['/home/karan/Downloads/Step_sis_/Step_sis_01.jpg', '/home/karan/Downloads/Step_sis_/Step_sis_02.jpg', '/home/karan/Downloads/Step_sis_/Step_sis_03.jpg', '/home/karan/Downloads/Step_sis_/Step_sis_04.jpg', '/home/karan/Downloads/Step_sis_/Step_sis_05.jpg', '/home/karan/Downloads/Step_sis_/Step_sis_06.jpg', '/home/karan/Downloads/Step_sis_/Step_sis_07.jpg', '/home/karan/Downloads/Step_sis_/Step_sis_08.jpg', '/home/karan/Downloads/Step_sis_/Step_sis_09.jpg', '/home/karan/Downloads/Step_sis_/Step_sis_10.jpg', '/home/karan/Downloads/Step_sis_/Step_sis_11.jpg', '/home/karan/Downloads/Step_sis_/Step_sis_12.jpg', '/home/karan/Downloads/Step_sis_/Step_sis_13.jpg', '/home/karan/Downloads/Step_sis_/Step_sis_14.jpg', '/home/karan/Downloads/Step_sis_/Step_sis_15.jpg', '/home/karan/Downloads/Step_sis_/Step_sis_16.jpg', '/home/karan/Downloads/Step_sis_/Step_sis_17.jpg', '/home/karan/Downloads/Step_sis_/Step_sis_18.jpg', '/home/karan/Downloads/Step_sis_/Step_sis_19.jpg', '/home/karan/Downloads/Step_sis_/Step_sis_20.jpg', '/home/karan/Downloads/Step_sis_/Step_sis_21.jpg', '/home/karan/Downloads/Step_sis_/Step_sis_22.jpg', '/home/karan/Downloads/Step_sis_/Step_sis_23.jpg']

# %%
with open("Comix/" + title + ".pdf", "wb") as f:
    f.write(img2pdf.convert([i for i in img_arr if i.endswith(".jpg")]))#os.listdir(directory)

# %%
app = Flask(__name__)

cors = CORS(app)
app.config['CORS_HEADERS'] = 'Content-Type'

methods = ('GET', 'POST')

metric_finders = {}
metric_readers = {}
annotation_readers = {}
panel_readers = {}

@app.route('/', methods=methods)
@cross_origin()
def hello_world():
    print(request.headers, request.get_json())
    return 'Jether\'s python Grafana datasource, used for rendering HTML panels and timeseries data.'

@app.route('/file')
def root():
    return app.send_static_file('index.html')

# %%
url_ = "https://www.porncomix.info/dna-2-jabcomix/"

r = get(url_)
title = 'DNA_'

directory = '/home/karan/Downloads/' + title + '/'
os.mkdir(directory)

html = BeautifulSoup(r.content,"html.parser")

count = 0

img_arr = []

for img_page in html.find_all("dt", class_="gallery-icon portrait"):
    #print(img_page)    
    for a in img_page.find_all("a", href=True):
        count = count + 1
        #print(a.attrs['href'])
        b = get(a.attrs['href'])
        
        if count < 10:
            count_str = "0" + str(count)
        else:
            count_str = str(count)
        
        page_img = BeautifulSoup(b.content,"html.parser").find_all("div", class_="attachment-image")[0].find_all("a", href=True)[0].attrs['href']
        
        c = get(page_img)
        
        img_arr.append('/home/karan/Downloads/' + title + '/' + title + (count_str) + ".jpg")
        
        with open('/home/karan/Downloads/' + title + '/' + title + (count_str) + ".jpg", 'wb') as f:
            f.write(c.content)
            print(title + (count_str))
            
print(img_arr)


with open("Comix/" + title + ".pdf", "wb") as f:
    f.write(img2pdf.convert([i for i in img_arr if i.endswith(".jpg")]))

# %%
for img_page in html.find_all("div", class_="gallery-icon"):
    print(img_page)
    for a in img_page.find_all("a", href=True):
        print(a)

# %%
with open('/home/karan/Downloads/cat3.jpg', 'wb') as f:
    f.write(r.content)
